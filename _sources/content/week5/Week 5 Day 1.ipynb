# %% [markdown]
# # `numpy` Matrix Basix
# This week we are going to focus on linear algebra and optimization methods in Python. Today, we'll re-introduce matrices.

# %%
# preliminaries

import numpy as np

# %% [markdown]
# ### Vectors
# Recalling your experiences in Math 220, we typically start linear algebra with vector operations. In Python, typically, vectors are one-dimensional numpy arrays:

# %%
x = np.array([1,2,3,4])
y = np.array([-1,0,2,0])

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
print(x + y)
print(x - y)
# Out:
# [0 2 5 4]
# [2 2 1 4]

# %% [markdown]
# Remember why numpy arrays are so nice: they act like numbers! We can add/subtract vectors:

# %% [markdown]
# We can scale vectors:

# %%
2 * x
# Out:
# array([2, 4, 6, 8])

# %% [markdown]
# We can also take the dot product of vectors:

# %%
print(np.dot(x, y))
print(x @ y)
# Out:
# 5
# 5

# %%
np.outer(x,y)
# Out:
# array([[-1,  0,  2,  0],
#        [-2,  0,  4,  0],
#        [-3,  0,  6,  0],
#        [-4,  0,  8,  0]])

# %% [markdown]
# The norm a vector can be easily computed so that we can normalize:

# %%
norm = np.linalg.norm(x)

normalizedx = x/norm

print(norm)
print(normalizedx)
print(np.linalg.norm(normalizedx))
# Out:
# 5.477225575051661
# [0.18257419 0.36514837 0.54772256 0.73029674]
# 0.9999999999999999

# %% [markdown]
# ### Matrices
# We can likewise perform operations on matrices!
#
# To define a matrix, we can do two things:

# %%
A = np.array([[1,2],
              [3,4]])

B = np.array([1,2,3,4]).reshape(2,2)

print(A)
print(B)
# Out:
# [[1 2]
#  [3 4]]
# [[1 2]
#  [3 4]]

# %% [markdown]
# If you need to know a matrix's size, simply use the `.shape` attribute:

# %%
A.shape
# Out:
# (2, 2)

# %% [markdown]
# Still, these are numpy arrays. Basic operations work exactly as we would like:

# %%
print(A + B)
print(3 * A)
# Out:
# [[2 4]
#  [6 8]]
# [[ 3  6]
#  [ 9 12]]

# %% [markdown]
# To perform matrix multiplication, we simply use `np.dot()` or `@`:

# %%
print(np.dot(A, B))
print(A @ B)
# Out:
# [[ 7 10]
#  [15 22]]
# [[ 7 10]
#  [15 22]]

# %%
print(A*B) # elementwise multiplication
# Out:
# [[ 1  4]
#  [ 9 16]]

# %% [markdown]
# We can compute the transpose in a couple ways:

# %%
print(A.T )
print(np.transpose(A))
# Out:
# [[1 3]
#  [2 4]]
# [[1 3]
#  [2 4]]

# %% [markdown]
# For the typical properties of matrices we like, numpy has them built in!

# %%
# inverse

print(np.linalg.inv(A))

# determinant

print(np.linalg.det(A))

# rank

print(np.linalg.matrix_rank(A))

# trace

print(np.trace(A))

# eigenvalues/eigenvectors

print(np.linalg.eig(A))
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]
# -2.0000000000000004
# 2
# 5
# (array([-0.37228132,  5.37228132]), array([[-0.82456484, -0.41597356],
#        [ 0.56576746, -0.90937671]]))

# %%
np.linalg.eig(A)[1]
# Out:
# array([[-0.82456484, -0.41597356],
#        [ 0.56576746, -0.90937671]])

# %% [markdown]
# ### Lab Problems
#
# ---
#
# 1.
# Write your own function performs vectors addition on lists instead of arrays.
#
# ---
#
# 2.
# Create two $3\times 2$ matrices, A and B. Compute:
# - A+B
# - AB
#
# ---
#
# 3.
# Make a 2 by 2 invertible matrix, A.
# - Compute its eigenvectors and plot them using matplotlib
# - Compute A times the eigenvectors and plot them on the same plot.
# - What do you notice?
#
# ---
#
# 4.
# Write your own function that creates a random 3 by 3 matrix using `np.random` for the entries.

# %% [markdown]
# ### Lab Key*
#
# ---
#
# 1.

# %% [markdown]
# ---
#
# 2.

# %% [markdown]
# ---
#
# 3.

# %% [markdown]
# ---
#
# 4.
