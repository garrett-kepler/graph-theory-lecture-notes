# %% [markdown]
# # `math`, `numpy`, & `sympy` Libraries
#
#
# Three of the most commonly used libraries in Python are **math**, **NumPy**, and **SymPy**. We went over numpy yesterday. Let's go over math and sympy today.
#
# Although they all perform mathematical operations, each library is designed for a different purpose.
#
# | Library | Typical Use | Good For |
# |----------|-------------|----------|
# | `math` | Standard mathematical functions | Individual numbers (scalars) |
# | `NumPy` | Numerical computing | Arrays, vectors, and matrices |
# | `SymPy` | Symbolic mathematics | Algebra, calculus, and exact arithmetic |

# %% [markdown]
# ### The `math` Library
#
# Python's math library comes built-in and provides functions for common mathematical operations on <i>scalars</i>.

# %%
import math
import numpy as np

# %%
print(math.sqrt(25))         # square root
print(math.sin(math.pi/2))   # sine
print(math.cos(0))           # cosine
print(math.log(10))          # natural logarithm
print(math.exp(2))           # exponential (e^x)
print(math.factorial(5))     # factorial
# Out:
# 5.0
# 1.0
# 1.0
# 2.302585092994046
# 7.38905609893065
# 120

# %%
math.e
# Out:
# 2.718281828459045

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'pi',
#  'pow',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
math.sin(1)
# Out:
# 0.8414709848078965

# %% [markdown]
# ### The `sympy` Library
#
# SymPy performs what we call <i>symbolic mathematics</i> rather than solving numerically like in numpy. To do this, we reform arithmetic in terms of a "sympy symbol". This object takes much longer to process and deal with than floats, so be careful!

# %%
import sympy as sp

# %% [markdown]
# To create a variable in sympy, we must tell Python to create a sympy symbol object:

# %%
x = sp.symbols('x')

# %% [markdown]
# Now, anytime the variable `x` is mentioned, Python knows to refer to the sympy-based arithmetic of the object. One basic operation in sympy is simplification:

# %%
print(sp.simplify((x**2 - 1)/(x - 1)))
# Out:
# x + 1

# %% [markdown]
# Also, expansion:

# %%
print(sp.expand((x + 2)**5))
# Out:
# x**5 + 10*x**4 + 40*x**3 + 80*x**2 + 80*x + 32

# %% [markdown]
# We can also factor polynomials:

# %%
print(sp.factor(x**2 - 9))
# Out:
# (x - 3)*(x + 3)

# %% [markdown]
# And solve quadratics:

# %%
solution = sp.solve(x**2 - 4, x) # sp.solve( function, variable )
print(solution)
# Out:
# [-2, 2]

# %% [markdown]
# Or evaluate limits:

# %%
print(sp.limit(sp.sin(x)/x, x, 0)) # sp.limit( function, variable, limit )
# Out:
# 1

# %% [markdown]
# Even differentiate:

# %%
f = x**3 + 2*x**2 - x
print(sp.diff(f, x))
# Out:
# 3*x**2 + 4*x - 1

# %% [markdown]
# And integrate:

# %%
print(sp.integrate(x**2, x)) # indefinite integral format

print(sp.integrate(x**2, (x, 0, 4))) # definite integral (from 0 to 4)
# Out:
# x**3/3
# 64/3

# %%
dir(sp)
# Out:
# ['Abs',
#  'AccumBounds',
#  'Add',
#  'Adjoint',
#  'AlgebraicField',
#  'AlgebraicNumber',
#  'And',
#  'AppliedPredicate',
#  'Array',
#  'AssumptionsContext',
#  'Atom',
#  'AtomicExpr',
#  'BasePolynomialError',
#  'Basic',
#  'BlockDiagMatrix',
#  'BlockMatrix',
#  'C',
#  'CC',
#  'CRootOf',
#  'Catalan',
#  'Chi',
#  'Ci',
#  'Circle',
#  'ClassRegistry',
#  'CoercionFailed',
#  'Complement',
#  'ComplexField',
#  'ComplexRegion',
#  'ComplexRootOf',
#  'Complexes',
#  'ComputationFailed',
#  'ConditionSet',
#  'Contains',
#  'CosineTransform',
#  'Curve',
#  'DeferredVector',
#  'DenseNDimArray',
#  'Derivative',
#  'Determinant',
#  'DiagonalMatrix',
#  'DiagonalOf',
#  'Dict',
#  'DiracDelta',
#  'Domain',
#  'DomainError',
#  'DotProduct',
#  'Dummy',
#  'E',
#  'E1',
#  'EPath',
#  'EX',
#  'Ei',
#  'Eijk',
#  'Ellipse',
#  'EmptySequence',
#  'EmptySet',
#  'Eq',
#  'Equality',
#  'Equivalent',
#  'EulerGamma',
#  'EvaluationFailed',
#  'ExactQuotientFailed',
# ...

# %% [markdown]
# ### Lab Problems
#
# ---
#
# 1.
# Import `numpy`, `math`, and `sympy`.
#
# ---
#
# 2.
# - Write a recursive function `factorial()` that takes in a natural number `n` and computes $n!=n(n-1)(n-2)\cdots3\cdot2\cdot 1$.
# - Use `%timeit` to determine how fast your function calculates `factorial(150)`.
# - Use `%timeit` to calculate how fast `math.factorial()` calculates the same quantity.
# - Were there any differences between the two methods?
#
# ---
#
# 3.
#
# Recall for a quadratic equation of the form
#
# $$ax^2 + bx + c = 0$$
#
# The solutions are given by the <i>quadratic formula</i>:
#
# $$x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}$$
#
# - Write a function `quadratic()` that calculates the two roots given by the quadratic formula only if they are real.
# - Use `%timeit` to determine how fast your function calculates the roots for $437x^2 - 915x + 478 = 0$.
# - Use `%timeit` to calculate how fast `sp.solve()` calculates the same quantities.
# - Were there any differences between the two methods?
#
# ---
#
# 4.
#
# For each of the following functions, use `sympy` calculate the first derivative, the second derivative, and the integral (all with respect to $x$):
#
# - $f(x)=x$
# - $f(x)=6x^{-1/2}$
# - $f(x)=\pi\sqrt{x}+x^5+7$
# - $f(x)=x(2x-5)(3+\tan(x))$
#
# ---
#
# 5.
#
# From yesterday, we calculated <i>numerically</i> what the derivative of $\sin(x)$ is.
# 1. Using sympy, calculate derivative at 0.
# 2. Using sympy, evaluate the limit definition of the derivative for $f(x)=\sin(x)$:
#
# $$f'(x)=\lim_{h\to0}\frac{f(x+h)-f(x)}{h}$$

# %% [markdown]
# ### Lab Key*
#
# ---
#
#
# 1.

# %%
import numpy as np
import math
import sympy as sp

# %% [markdown]
# ---
#
# 2.

# %%
def factorial(n):
    if n < 0:
        print('no')
    elif n == 0:
        return 1
    else:
        return n*factorial(n-1)
# %timeit factorial(150)
# %timeit math.factorial(150)
# Out:
# 34.8 μs ± 1.64 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 3 μs ± 210 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ---
#
# 3.

# %%
def quadratic(a, b, c):
    if b**2-4*a*c<0:
        print('not real')
    else:
        x = -b/(2*a)
        y = np.sqrt(b**2-4*a*c)/(2*a)
        return [x+y, x-y]
        
x = sp.symbols('x')

# %timeit quadratic(437, -915, 478)
# %timeit sp.solve(437*x**2-915*x+478, x)
# Out:
# 4 μs ± 245 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.15 ms ± 284 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ---
#
# 4.

# %%
def alltogether(f):
    return [sp.diff(f, x, 1), sp.diff(f, x, 2), sp.integrate(f, x)]
x = sp.symbols('x')

print(alltogether(x))

print(alltogether(6*x**(-.5)))

print(alltogether(sp.pi*sp.sqrt(x)+x**5+7))

print(alltogether(x*(2*x-5)*(3+sp.tan(x))))
# Out:
# [1, 0, x**2/2]
# [-3.0/x**1.5, 4.5/x**2.5, 12.0*x**0.5]
# [5*x**4 + pi/(2*sqrt(x)), 20*x**3 - pi/(4*x**(3/2)), 2*pi*x**(3/2)/3 + x**6/6 + 7*x]
# [x*(2*x - 5)*(tan(x)**2 + 1) + 2*x*(tan(x) + 3) + (2*x - 5)*(tan(x) + 3), 2*(x*(2*x - 5)*(tan(x)**2 + 1)*tan(x) + 2*x*(tan(x)**2 + 1) + (2*x - 5)*(tan(x)**2 + 1) + 2*tan(x) + 6), Integral(x*(2*x - 5)*(tan(x) + 3), x)]

# %% [markdown]
# ---
#
# 5.

# %%
sp.diff(sp.sin(x)).subs(x, 0)
h = sp.symbols('h')
sp.limit((sp.sin(x+h)-sp.sin(x))/h,h, 0)
# Out:
# cos(x)
