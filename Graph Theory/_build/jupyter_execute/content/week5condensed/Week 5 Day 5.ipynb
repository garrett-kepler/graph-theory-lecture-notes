# %% [markdown]
# # Optimization in Linear Algebra

# %%
# preliminaries

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Recall: Eigenvalues
#
# An eigenvector is a vector $v$ such that
#
# $$Av=\lambda v.$$
#
# where
# - $A$ is a matrix
# - $\lambda$ is a scalar (called the eigenvalue)

# %% [markdown]
# Suppose
# $
# A=
# \begin{bmatrix}
# 4 & 1\\
# 1 & 3
# \end{bmatrix}$ Note that $A=A^T$. We call these matrices *symmetric*. We can compute the eigenvalues and eigenvectors as follows:

# %%
A = np.array([[4,1],[1,3]])
A @ np.linalg.eig(A)[1][:,1]
# Out:
# array([-1.25227364,  2.02622131])

# %%
np.linalg.eig(A)[0][1]*np.array([-0.52573111,  0.85065081])
# Out:
# array([-1.25227364,  2.02622132])

# %% [markdown]
# ### Quadratic Forms
#
# Consider
#
# $$f(x)=x^TAx$$
#
# This is called a **quadratic form**. If
#
# ```python
# x = [x_1, x_2]
# ```
# then
#
# ```python
# A =
# [[4,1],
#  [1,3]]
# ```
#
# gives
#
# $$f(x)=4x_1^2+2x_1x_2+3x_2^2.$$
#
# Quadratic forms appear throughout optimization. Most importantly, in eigenvalues.
#
# ### The Rayleigh Quotient
#
# The quantity
#
# $$R(A)=\frac{x^TAx}{x^Tx}$$
#
# is called the **Rayleigh Quotient**.
#
# One of the most important theorems in linear algebra states
#
# $$\lambda_{\min}(A)\leq R(A)\leq \lambda_{\max}(A)$$
#
# And that for symmetric matrices $\min_{x\neq 0}R(A)=\lambda_{\min}$ and $\max_{x\neq 0}R(A)=\lambda_{\max}$ where the $x$'s that acheive these values are the eigenvectors.
#
# Consider drawing these randomly:

# %%
values, vectors = np.linalg.eig(A)

largest = np.max(values)
smallest = np.min(values)

samples = []

for i in range(5000):
    x = np.random.randn(2)
    x = x/np.linalg.norm(x)

    value = x.T @ A @ x

    samples.append(value)

print(str(max(samples))+" was the biggest random sample vs the largest eigenvalue "+str(largest))
print(str(min(samples))+" was the smallest random sample vs the smallest eigenvalue "+str(smallest))
# Out:
# 4.618031785913046 was the biggest random sample vs the largest eigenvalue 4.618033988749895
# 2.381966012308271 was the smallest random sample vs the smallest eigenvalue 2.381966011250105

# %%
plt.scatter([i for i in range(len(samples))],
            samples,
            label='Samples',
            s=1)
plt.axhline(largest, 
            color='red',
            label=r'$\lambda_{\max}$')
plt.axhline(smallest, 
            color='green',
            label=r'$\lambda_{\min}$', 
            linestyle='--')
plt.xlabel('Sample Number')
plt.ylabel('R(A)')
plt.title('Random Rayleigh')
plt.legend(bbox_to_anchor=(1.05, 1))

# %% [markdown]
# Note that indeed every single value of $R(A)$ lies within the bounds!

# %% [markdown]
# ### Lab Problems
#
# ---
#
# 1. Write a function that uses `scipy.optimize` to find the largest and smallest eigenvalue of a symmetric two by two matrix.
#
# ---
#
# 2. Write a function that randomly samples vectors to approximate the largest and smallest eigenvalues. Make this function print the error as well.
#
# ---
#
# 3. Generalize the function from Problem 1 for arbitrary sized matrices.

# %% [markdown]
# ### Lab Key*

# %% [markdown]
# 1.

# %% [markdown]
# 2.

# %% [markdown]
# 3.
