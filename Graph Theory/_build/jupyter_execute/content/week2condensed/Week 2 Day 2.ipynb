# %% [markdown]
# # Working with Libraries
# Today we'll be talking about libraries and how to use them.
#
# First of all, what is a <i>library</i>? A library is simply a collection of functions that others have written, tested, and (likely) optimized for everyone to use. While some coding languages require you to pay for these libraries, Python is <i>open-source</i> meaning anyone can contribute and no one pays.
#
# Two important libraries we will need today should be built in: `numpy` and `math`. To have access to a library, we need to <i>install</i> the library to our system. For example, with `numpy`,

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (2.4.6)

# %% [markdown]
# To use a library, we need to <i>import</i> the library into the notebook we are currently using,

# %%
import math
import numpy

# %% [markdown]
# <u>Important:</u> If you ever find that you do not have a library downloaded, you can try installing it by running this in your notebook: `!pip install library_name`. Just like the functions we design, all the functions in these libraries are typically dependent on other libraries or base code called <i>dependencies</i>. When using `!pip install`, your system will typically download and/or update these as well to match whatever version of the library you are downloading.

# %% [markdown]
# To use libraries, we typically have to write `library_we_want.function_we_want()`. Since we might end up writing the same library name hundreds of times, we can assign a variable to the name of the library when we import if we want to:

# %%
import numpy as np

# %% [markdown]
# Every library comes with an instruction manual called <i>documentation</i> that allows you to find what is required to run a specific library's function. For example, here is `numpy`'s and `math`'s: https://numpy.org/doc/ and https://docs.python.org/3/library/math.html . You should always try referring to the documentation for troubleshooting.
#
# If you forget what the function name is in whatever library you are looking at, `dir()` will list out all of them for you:

# %%
dir(np)
# Out:
# ['False_',
#  'ScalarType',
#  'True_',
#  '_CopyMode',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__array_api_version__',
#  '__array_namespace_info__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__expired_attributes__',
#  '__file__',
#  '__former_attrs__',
#  '__future_scalars__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__numpy_submodules__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_array_api_info',
#  '_core',
#  '_distributor_init',
#  '_expired_attrs_2_0',
#  '_globals',
#  '_int_extended_msg',
#  '_mat',
#  '_msg',
#  '_pyinstaller_hooks_dir',
#  '_pytesttester',
#  '_specific_msg',
#  '_type_info',
#  '_typing',
#  '_utils',
#  'abs',
#  'absolute',
#  'acos',
#  'acosh',
#  'add',
#  'all',
#  'allclose',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
#  'apply_over_axes',
#  'arange',
#  'arccos',
#  'arccosh',
#  'arcsin',
#  'arcsinh',
#  'arctan',
#  'arctan2',
#  'arctanh',
#  'argmax',
#  'argmin',
#  'argpartition',
#  'argsort',
#  'argwhere',
#  'around',
#  'array',
#  'array2string',
#  'array_equal',
#  'array_equiv',
#  'array_repr',
#  'array_split',
#  'array_str',
#  'asanyarray',
#  'asarray',
#  'asarray_chkfinite',
#  'ascontiguousarray',
#  'asfortranarray',
#  'asin',
#  'asinh',
#  'asmatrix',
#  'astype',
#  'atan',
#  'atan2',
#  'atanh',
#  'atleast_1d',
#  'atleast_2d',
#  'atleast_3d',
#  'average',
#  'bartlett',
#  'base_repr',
#  'binary_repr',
#  'bincount',
#  'bitwise_and',
#  'bitwise_count',
#  'bitwise_invert',
#  'bitwise_left_shift',
#  'bitwise_not',
#  'bitwise_or',
#  'bitwise_right_shift',
#  'bitwise_xor',
#  'blackman',
#  'block',
#  'bmat',
#  'bool',
#  'bool_',
#  'broadcast',
#  'broadcast_arrays',
#  'broadcast_shapes',
#  'broadcast_to',
#  'busday_count',
#  'busday_offset',
#  'busdaycalendar',
#  'byte',
#  'bytes_',
#  'c_',
#  'can_cast',
#  'cbrt',
#  'cdouble',
#  'ceil',
#  'char',
#  'character',
#  'choose',
#  'clip',
#  'clongdouble',
#  'column_stack',
#  'common_type',
#  'complex128',
#  'complex64',
#  'complexfloating',
#  'compress',
#  'concat',
#  'concatenate',
#  'conj',
#  'conjugate',
#  'convolve',
#  'copy',
#  'copysign',
#  'copyto',
#  'core',
#  'corrcoef',
#  'correlate',
#  'cos',
#  'cosh',
#  'count_nonzero',
#  'cov',
#  'cross',
#  'csingle',
#  'ctypeslib',
#  'cumprod',
#  'cumsum',
#  'cumulative_prod',
#  'cumulative_sum',
#  'datetime64',
#  'datetime_as_string',
#  'datetime_data',
#  'deg2rad',
#  'degrees',
#  'delete',
#  'diag',
#  'diag_indices',
#  'diag_indices_from',
#  'diagflat',
#  'diagonal',
#  'diff',
#  'digitize',
#  'divide',
#  'divmod',
#  'dot',
#  'double',
#  'dsplit',
#  'dstack',
#  'dtype',
#  'dtypes',
#  'e',
#  'ediff1d',
#  'einsum',
#  'einsum_path',
#  'emath',
#  'empty',
#  'empty_like',
#  'equal',
#  'errstate',
#  'euler_gamma',
#  'exceptions',
#  'exp',
#  'exp2',
#  'expand_dims',
#  'expm1',
#  'extract',
#  'eye',
#  'f2py',
#  'fabs',
#  'fft',
#  'fill_diagonal',
#  'finfo',
#  'fix',
#  'flatiter',
#  'flatnonzero',
#  'flexible',
#  'flip',
#  'fliplr',
#  'flipud',
#  'float16',
#  'float32',
#  'float64',
#  'float_power',
#  'floating',
#  'floor',
#  'floor_divide',
#  'fmax',
#  'fmin',
#  'fmod',
#  'format_float_positional',
#  'format_float_scientific',
#  'frexp',
#  'from_dlpack',
#  'frombuffer',
#  'fromfile',
#  'fromfunction',
#  'fromiter',
#  'frompyfunc',
#  'fromregex',
#  'fromstring',
#  'full',
#  'full_like',
#  'gcd',
#  'generic',
#  'genfromtxt',
#  'geomspace',
#  'get_include',
#  'get_printoptions',
#  'getbufsize',
#  'geterr',
#  'geterrcall',
#  'gradient',
#  'greater',
#  'greater_equal',
#  'half',
#  'hamming',
#  'hanning',
#  'heaviside',
#  'histogram',
#  'histogram2d',
#  'histogram_bin_edges',
#  'histogramdd',
#  'hsplit',
#  'hstack',
#  'hypot',
#  'i0',
#  'identity',
#  'iinfo',
#  'imag',
#  'index_exp',
#  'indices',
#  'inexact',
#  'inf',
#  'info',
#  'inner',
#  'insert',
#  'int16',
#  'int32',
#  'int64',
#  'int8',
#  'int_',
#  'intc',
#  'integer',
#  'interp',
#  'intersect1d',
#  'intp',
#  'invert',
#  'is_busday',
#  'isclose',
#  'iscomplex',
#  'iscomplexobj',
#  'isdtype',
#  'isfinite',
#  'isfortran',
#  'isin',
#  'isinf',
#  'isnan',
#  'isnat',
#  'isneginf',
#  'isposinf',
#  'isreal',
#  'isrealobj',
#  'isscalar',
#  'issubdtype',
#  'iterable',
#  'ix_',
#  'kaiser',
#  'kron',
#  'lcm',
#  'ldexp',
#  'left_shift',
#  'less',
#  'less_equal',
#  'lexsort',
#  'lib',
#  'linalg',
#  'linspace',
#  'little_endian',
#  'load',
#  'loadtxt',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'logaddexp',
#  'logaddexp2',
#  'logical_and',
#  'logical_not',
#  'logical_or',
#  'logical_xor',
#  'logspace',
#  'long',
#  'longdouble',
#  'longlong',
#  'ma',
#  'mask_indices',
#  'matmul',
#  'matrix',
#  'matrix_transpose',
#  'matvec',
#  'max',
#  'maximum',
#  'may_share_memory',
#  'mean',
#  'median',
#  'memmap',
#  'meshgrid',
#  'mgrid',
#  'min',
#  'min_scalar_type',
#  'minimum',
#  'mintypecode',
#  'mod',
#  'modf',
#  'moveaxis',
#  'multiply',
#  'nan',
#  'nan_to_num',
#  'nanargmax',
#  'nanargmin',
#  'nancumprod',
#  'nancumsum',
#  'nanmax',
#  'nanmean',
#  'nanmedian',
#  'nanmin',
#  'nanpercentile',
#  'nanprod',
#  'nanquantile',
#  'nanstd',
#  'nansum',
#  'nanvar',
#  'ndarray',
#  'ndenumerate',
#  'ndim',
#  'ndindex',
#  'nditer',
#  'negative',
#  'nested_iters',
#  'newaxis',
#  'nextafter',
#  'nonzero',
#  'not_equal',
#  'number',
#  'object_',
#  'ogrid',
#  'ones',
#  'ones_like',
#  'outer',
#  'packbits',
#  'pad',
#  'partition',
#  'percentile',
#  'permute_dims',
#  'pi',
#  'piecewise',
#  'place',
#  'poly',
#  'poly1d',
#  'polyadd',
#  'polyder',
#  'polydiv',
#  'polyfit',
#  'polyint',
#  'polymul',
#  'polynomial',
#  'polysub',
#  'polyval',
#  'positive',
#  'pow',
#  'power',
#  'printoptions',
#  'prod',
#  'promote_types',
#  'ptp',
#  'put',
#  'put_along_axis',
#  'putmask',
#  'quantile',
#  'r_',
#  'rad2deg',
#  'radians',
#  'random',
#  'ravel',
#  'ravel_multi_index',
#  'real',
#  'real_if_close',
#  'rec',
#  'recarray',
#  'reciprocal',
#  'record',
#  'remainder',
#  'repeat',
#  'require',
#  'reshape',
#  'resize',
#  'result_type',
#  'right_shift',
#  'rint',
#  'roll',
#  'rollaxis',
#  'roots',
#  'rot90',
#  'round',
#  'row_stack',
#  's_',
#  'save',
#  'savetxt',
#  'savez',
#  'savez_compressed',
#  'sctypeDict',
#  'searchsorted',
#  'select',
#  'set_printoptions',
#  'setbufsize',
#  'setdiff1d',
#  'seterr',
#  'seterrcall',
#  'setxor1d',
#  'shape',
#  'shares_memory',
#  'short',
#  'show_config',
#  'show_runtime',
#  'sign',
#  'signbit',
#  'signedinteger',
#  'sin',
#  'sinc',
#  'single',
#  'sinh',
#  'size',
#  'sort',
#  'sort_complex',
#  'spacing',
#  'split',
#  'sqrt',
#  'square',
#  'squeeze',
#  'stack',
#  'std',
#  'str_',
#  'strings',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'take',
#  'take_along_axis',
#  'tan',
#  'tanh',
#  'tensordot',
#  'test',
#  'testing',
#  'tile',
#  'timedelta64',
#  'trace',
#  'transpose',
#  'trapezoid',
#  'tri',
#  'tril',
#  'tril_indices',
#  'tril_indices_from',
#  'trim_zeros',
#  'triu',
#  'triu_indices',
#  'triu_indices_from',
#  'true_divide',
#  'trunc',
#  'typecodes',
#  'typename',
#  'typing',
#  'ubyte',
#  'ufunc',
#  'uint',
#  'uint16',
#  'uint32',
#  'uint64',
#  'uint8',
#  'uintc',
#  'uintp',
#  'ulong',
#  'ulonglong',
#  'union1d',
#  'unique',
#  'unique_all',
#  'unique_counts',
#  'unique_inverse',
#  'unique_values',
#  'unpackbits',
#  'unravel_index',
#  'unsignedinteger',
#  'unstack',
#  'unwrap',
#  'ushort',
#  'vander',
#  'var',
#  'vdot',
#  'vecdot',
#  'vecmat',
#  'vectorize',
#  'void',
#  'vsplit',
#  'vstack',
#  'where',
#  'zeros',
#  'zeros_like']

# %% [markdown]
# ### Numpy
# Numpy is one of the most crucial libraries when doing mathematical computing. The reason numpy is so useful is its computational efficiency in most regards.
#
# Numpy introduces a different type of object to the list of Python objects we know now: the numpy array. Similar to a list, a numpy array is a collection of objects. However, unlike a list, applying a function to a numpy array applies the function immediately to the elements.

# %%
contlist = [1, 1, 4, 5, 2, 6] # a list
contarray = np.array(contlist) # the numpy array version
type(contlist), type(contarray)
# Out:
# (list, numpy.ndarray)

# %%
contlist[0]
# Out:
# 1

# %% [markdown]
# The only restriction on numpy array elements are that they are all the <u>same type of object</u>. If not, then numpy will often make them the same type.

# %%
np.array([1, '1'])
# Out:
# array(['1', '1'], dtype='<U21')

# %% [markdown]
# So, how do we work with numpy arrays? The way we would work with numbers (not lists).

# %%
4 * contlist + [1]
# Out:
# [1, 1, 4, 5, 2, 6, 1, 1, 4, 5, 2, 6, 1, 1, 4, 5, 2, 6, 1, 1, 4, 5, 2, 6, 1]

# %%
contarray
# Out:
# array([1, 1, 4, 5, 2, 6])

# %%
4 * contarray + 1
# Out:
# array([ 5,  5, 17, 21,  9, 25])

# %% [markdown]
# We also get a speed up when inputting functions:

# %%
n = 100000
x = np.linspace(0, 2*np.pi, n)

# %%
x
# Out:
# array([0.00000000e+00, 6.28324814e-05, 1.25664963e-04, ...,
#        6.28305964e+00, 6.28312247e+00, 6.28318531e+00], shape=(100000,))

# %%
# using list indexing
# %timeit y = [math.sin(x[i]) + math.exp(x[i]**2) for i in range(n)]

# using numpy ufuncs
# %timeit y = np.sin(x) + np.exp(x**2)
# Out:
# 75.1 ms ± 1.78 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.88 ms ± 70.6 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# The reason for this speed up is called <i> vectorization </i>. Numpy functions that act on arrays (called <i> universal functions </i> or <i> ufuncs</i>) are designed to execute a single instruction on an entire data set using hardware instructions giving a dramatic speed up in most scenarios.
#
# We can design functions so that they benefit from this same speed up as well. That is, we can <i>vectorize</i> a function:

# %%
def f(n):
    return math.sin(n) + math.exp(n**2)

# %%
x
# Out:
# array([0.00000000e+00, 6.28324814e-05, 1.25664963e-04, ...,
#        6.28305964e+00, 6.28312247e+00, 6.28318531e+00], shape=(100000,))

# %%
# method 1


vectf = map(f, x) # for each element in a vector x, apply f

# %%
# method 2


g = np.vectorize(f)

# %%
# %timeit out = list(map(f,x))

# %timeit out = g(x)

# %timeit out = np.sin(x) + np.exp(x**2)
# Out:
# 58.3 ms ± 1.52 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 56.3 ms ± 511 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.82 ms ± 5.01 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# Not only will numpy arrays speed up our computation for basic problems, but numpy arrays will be our matrix objects in the linear algebra section of this class:

# %%
contlist = np.array([1,2,3,4])
matrix = contlist.reshape(2,2)

# %%
matrix * matrix # element-wise multiplication
# Out:
# array([[ 1,  4],
#        [ 9, 16]])

# %%
matrix @ matrix # regular matrix multiplication
# Out:
# array([[ 7, 10],
#        [15, 22]])

# %% [markdown]
# ### Practice Lab Problems
# 1.
#
# If not already installed, install the numpy library using `!pip install numpy`. After installing, import numpy with variable name `np`.
#
# ---
#
# 2.
#
# We will use other libraries throughout this semester as well. Here are a couple:
#
# - `matplotlib`
# - `networkx`
# - `pandas`
# - `geopandas`
#
# Try importing these libraries. If they are not installed, use `pip install` to install them for future use.
#
# ---
#
# 3.
#
# Given
#
# ```python
# a = np.array([2, 4, 6, 8])
# ```
#
# compute each of the following:
#
# - `a + 3`
# - `2 * a`
# - `a**2`
# - `a - 1`
#
# Do not use a `for` loop.
#
# ---
#
# 4.
#
# The derivative of a function \(f(x)\) at a point \(x\) is defined as the limit
#
# $f'(x)=\lim_{h\to0}\frac{f(x+h)-f(x)}{h}$
#
# provided the limit exists.
#
# Define a function $g(h)$ that computes the quotient above for a given function $f$ near a point $x$. Then, vectorize $g$.
#
#
# Using `np.linspace()`, let $f(x)=sin(x)$ and compute $g$ at $10^{-1}, 10^{-2}, 10^{-3}, 10^{-4}$. This will be an estimate for the derivative of $f$. Compare to the actual derivative.
#
# ---
#
# 5.
# Let
#
# $$A=\begin{bmatrix}
# 2 & 1 \\
# 3 & 4
# \end{bmatrix}~~~~ B= \begin{bmatrix}
# 5 & 2 \\
# 1 & 6
# \end{bmatrix}$$
#
# Compute the product.

# %% [markdown]
# ### Lab Key*
# 1.

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (2.4.6)

# %%
import numpy as np

# %% [markdown]
# 2.

# %%
# !pip install matplotlib
# !pip install networkx
# !pip install pandas
# !pip install geopandas
# Out:
# Requirement already satisfied: matplotlib in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from matplotlib) (26.1)
# Requirement already satisfied: pillow>=9 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: networkx in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (3.6.1)
# Collecting pandas
#   Using cached pandas-3.0.5-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp311-cp311-win_amd64.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/10.0 MB 2.1 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/10.0 MB 1.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/10.0 MB 1.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/10.0 MB 1.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/10.0 MB 1.0 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.3/10.0 MB 1.0 MB/s eta 0:00:09
#    ------ --------------------------------- 1.6/10.0 MB 942.3 kB/s eta 0:00:09
#    ------ --------------------------------- 1.6/10.0 MB 942.3 kB/s eta 0:00:09
#    ------- -------------------------------- 1.8/10.0 MB 875.3 kB/s eta 0:00:10
#    -------- ------------------------------- 2.1/10.0 MB 870.1 kB/s eta 0:00:10
#    --------- ------------------------------ 2.4/10.0 MB 877.1 kB/s eta 0:00:09
#    --------- ------------------------------ 2.4/10.0 MB 877.1 kB/s eta 0:00:09
#    ---------- ----------------------------- 2.6/10.0 MB 883.0 kB/s eta 0:00:09
#    ---------- ----------------------------- 2.6/10.0 MB 883.0 kB/s eta 0:00:09
#    ----------- ---------------------------- 2.9/10.0 MB 822.5 kB/s eta 0:00:09
#    ----------- ---------------------------- 2.9/10.0 MB 822.5 kB/s eta 0:00:09
#    ----------- ---------------------------- 2.9/10.0 MB 822.5 kB/s eta 0:00:09
#    ------------ --------------------------- 3.1/10.0 MB 778.7 kB/s eta 0:00:09
#    ------------ --------------------------- 3.1/10.0 MB 778.7 kB/s eta 0:00:09
#    ------------- -------------------------- 3.4/10.0 MB 759.7 kB/s eta 0:00:09
#    -------------- ------------------------- 3.7/10.0 MB 765.3 kB/s eta 0:00:09
#    -------------- ------------------------- 3.7/10.0 MB 765.3 kB/s eta 0:00:09
#    --------------- ------------------------ 3.9/10.0 MB 777.7 kB/s eta 0:00:08
#    ---------------- ----------------------- 4.2/10.0 MB 796.5 kB/s eta 0:00:08
#    ----------------- ---------------------- 4.5/10.0 MB 811.0 kB/s eta 0:00:07
#    ------------------ --------------------- 4.7/10.0 MB 831.6 kB/s eta 0:00:07
#    ------------------ --------------------- 4.7/10.0 MB 831.6 kB/s eta 0:00:07
#    ------------------- -------------------- 5.0/10.0 MB 801.0 kB/s eta 0:00:07
#    ------------------- -------------------- 5.0/10.0 MB 801.0 kB/s eta 0:00:07
#    ------------------- -------------------- 5.0/10.0 MB 801.0 kB/s eta 0:00:07
#    ------------------- -------------------- 5.0/10.0 MB 801.0 kB/s eta 0:00:07
#    ------------------- -------------------- 5.0/10.0 MB 801.0 kB/s eta 0:00:07
#    --------------------- ------------------ 5.2/10.0 MB 727.8 kB/s eta 0:00:07
#    --------------------- ------------------ 5.2/10.0 MB 727.8 kB/s eta 0:00:07
#    --------------------- ------------------ 5.2/10.0 MB 727.8 kB/s eta 0:00:07
#    --------------------- ------------------ 5.2/10.0 MB 727.8 kB/s eta 0:00:07
#    ---------------------- ----------------- 5.5/10.0 MB 679.2 kB/s eta 0:00:07
#    ---------------------- ----------------- 5.5/10.0 MB 679.2 kB/s eta 0:00:07
#    ----------------------- ---------------- 5.8/10.0 MB 675.0 kB/s eta 0:00:07
#    ----------------------- ---------------- 5.8/10.0 MB 675.0 kB/s eta 0:00:07
#    ------------------------ --------------- 6.0/10.0 MB 681.0 kB/s eta 0:00:06
#    ------------------------- -------------- 6.3/10.0 MB 691.5 kB/s eta 0:00:06
#    -------------------------- ------------- 6.6/10.0 MB 702.7 kB/s eta 0:00:05
#    --------------------------- ------------ 6.8/10.0 MB 715.8 kB/s eta 0:00:05
#    ---------------------------- ----------- 7.1/10.0 MB 730.7 kB/s eta 0:00:04
#    ----------------------------- ---------- 7.3/10.0 MB 742.6 kB/s eta 0:00:04
#    ------------------------------ --------- 7.6/10.0 MB 750.4 kB/s eta 0:00:04
#    -------------------------------- ------- 8.1/10.0 MB 779.1 kB/s eta 0:00:03
#    --------------------------------- ------ 8.4/10.0 MB 791.6 kB/s eta 0:00:02
#    ---------------------------------- ----- 8.7/10.0 MB 806.1 kB/s eta 0:00:02
#    ------------------------------------ --- 9.2/10.0 MB 836.4 kB/s eta 0:00:01
#    ------------------------------------- -- 9.4/10.0 MB 851.0 kB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.0 MB 860.4 kB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 862.8 kB/s  0:00:11
# Installing collected packages: pandas
# Successfully installed pandas-3.0.5
# ^C
# Collecting geopandas
#   Using cached geopandas-1.1.4-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.24 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from geopandas) (2.4.6)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Using cached pyogrio-0.13.0-cp311-abi3-win_amd64.whl.metadata (6.0 kB)
# Requirement already satisfied: packaging in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from geopandas) (26.1)
# Requirement already satisfied: pandas>=2.0.0 in C:\Users\garre\miniconda3\envs\jbook\Lib\site-packages (from geopandas) (3.0.5)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Using cached pyproj-3.7.2-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.1.2-cp311-cp311-win_amd64.whl.metadata (7.1 kB)

# %% [markdown]
# 3.

# %%
a = np.array([2, 4, 6, 8])
print(a+3)
print(2*a)
print(a**2)
print(a-1)

# %% [markdown]
# 4.

# %%
import math

# %%
x = np.pi # some point x

def g(h):                  
    return (f(x+h)-f(x))/h  # quotient for derivative

G = np.vectorize(g)   # vectorize g
def f(x):
    return math.sin(x) # f of choice

h = np.linspace(-1, -4, 4)   # -1, -2, -3, -4
h = 10**h                   # 10^-1, 10^-2, 10^-3, 10^-4

print(G(h))                 # evalutate the vectorized version of g at h values
print(math.cos(np.pi))      # actual derivative

# %% [markdown]
# 5.

# %%
a = [2,1,3,4]
b = [5,2,1,6]
A = np.array(a).reshape(2,2)
B = np.array(b).reshape(2,2)
A @ B
