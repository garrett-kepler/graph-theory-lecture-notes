# %% [markdown]
# # Week 3 Day 3
#
# Today, we'll gain more experience using pandas to read and write datasets.

# %%
# preliminaries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %% [markdown]
# The main object in pandas is the <i>pandas dataframe</i> which is similar to a spreadsheet or table. Moreover, we can convert the dataframe into whatever format we like.
#
# For example, consider the following table.
#
# | Name | Age | Major |
# |------|----:|--------|
# | Alice | 20 | Mathematics |
# | Bob | 22 | Physics |
# | Charlie | 19 | Biology |
#
# If I wanted to convert this into a dataframe, I could do the following:

# %%
Name = ['Alice', 'Bob', 'Charlie']
Age = [20, 22, 19]
Major = ['Mathematics', 'Physics', 'Biology']

# %%
dataframe = pd.DataFrame({
    'Name': Name,
    'Age': Age,
    'Major': Major
})
dataframe
# Out:
#       Name  Age        Major
# 0    Alice   20  Mathematics
# 1      Bob   22      Physics
# 2  Charlie   19      Biology

# %%
type(dataframe)
# Out:
# pandas.DataFrame

# %% [markdown]
# Pandas will automatically store information about the dataframe that we can easily obtain:

# %%
dataframe.info() # basic information

dataframe.columns # column names

dataframe.shape # dimensions of dataframe
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      str
#  1   Age     3 non-null      int64
#  2   Major   3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes
# (3, 3)

# %% [markdown]
# Even basic statistical information we might wish to obtain:

# %%
dataframe.describe() # summary statistics
# Out:
#              Age
# count   3.000000
# mean   20.333333
# std     1.527525
# min    19.000000
# 25%    19.500000
# 50%    20.000000
# 75%    21.000000
# max    22.000000

# %% [markdown]
# We can also easily access data from the dataframe as well:

# %%
dataframe.head()
# Out:
#       Name  Age        Major
# 0    Alice   20  Mathematics
# 1      Bob   22      Physics
# 2  Charlie   19      Biology

# %%
dataframe.head(1)
# Out:
#     Name  Age        Major
# 0  Alice   20  Mathematics

# %%
dataframe.iloc[0]
# Out:
# Name           Alice
# Age               20
# Major    Mathematics
# Name: 0, dtype: object

# %%
dataframe.iloc[0:2]
# Out:
#     Name  Age        Major
# 0  Alice   20  Mathematics
# 1    Bob   22      Physics

# %%
dataframe['Age']
# Out:
# 0    20
# 1    22
# 2    19
# Name: Age, dtype: int64

# %%
dataframe[['Age', 'Major']]
# Out:
#    Age        Major
# 0   20  Mathematics
# 1   22      Physics
# 2   19      Biology

# %% [markdown]
# We've already had experience reading a `.csv` file into a notebook, now we will write our own:

# %%
dataframe.to_csv("dataframe.csv", index=False)

# %%
pd.read_csv("dataframe.csv")
# Out:
#       Name  Age        Major
# 0    Alice   20  Mathematics
# 1      Bob   22      Physics
# 2  Charlie   19      Biology

# %% [markdown]
# #  Lab Problems
#
# ---
#
# 1.
# - Create your own dataframe with at least 3 columns and 4 rows.
# - Save the dataframe to a csv file.
# - Read the csv back in.
# - Plot the data.
#
# ---
#
# 2.
# ```python
# list1 = [655, 115, 26, 760, 282, 251, 229, 143, 755, 105, 693, 759, 914, 559, 90, 605, 433, 33, 31, 96, 224, 239, 518, 617, 28, 575, 204, 734, 666, 719, 559, 430, 226, 460, 604, 285, 829, 891, 7, 778, 826, 164, 715, 433, 349, 285, 160, 221, 981, 782, 345, 105, 95, 390, 100, 368, 868, 353, 619, 271, 827, 45, 748, 471, 550, 128, 997, 945, 388, 81, 566, 301, 850, 644, 634, 907, 883, 371, 592, 197, 722, 72, 47, 678, 234, 792, 297, 82, 876, 239, 888, 104, 390, 285, 465, 651, 855, 374, 167, 380]
#
# list2 = [364, 215, 687, 274, 719, 960, 700, 664, 74, 624, 651, 176, 547, 747, 251, 168, 474, 389, 277, 948, 656, 705, 571, 225, 702, 333, 864, 787, 795, 58, 235, 842, 33, 825, 324, 411, 275, 68, 217, 936, 966, 581, 898, 736, 323, 218, 672, 512, 406, 906, 937, 659, 470, 147, 272, 143, 253, 763, 575, 552, 270, 765, 599, 439, 920, 598, 409, 371, 225, 142, 522, 506, 94, 774, 49, 882, 113, 157, 643, 164, 812, 697, 433, 611, 66, 395, 391, 611, 480, 542, 258, 995, 567, 882, 966, 12, 697, 739, 118, 699]
#
# list3 = [907, 550, 769, 274, 788, 657, 349, 115, 301, 446, 162, 465, 4, 977, 740, 897, 737, 270, 996, 513, 781, 183, 520, 935, 109, 892, 641, 306, 862, 655, 520, 624, 204, 157, 383, 781, 166, 553, 977, 798, 945, 544, 941, 1, 614, 332, 501, 20, 115, 952, 372, 900, 852, 827, 315, 246, 60, 247, 900, 581, 970, 81, 88, 750, 498, 836, 71, 779, 546, 785, 129, 132, 676, 487, 970, 563, 170, 272, 541, 894, 622, 434, 988, 217, 952, 553, 774, 748, 707, 206, 731, 320, 409, 688, 666, 383, 449, 922, 530, 463]
#
# list4 = [124, 254, 231, 66, 347, 22, 603, 568, 236, 603, 226, 8, 73, 725, 647, 61, 235, 70, 928, 33, 881, 339, 73, 527, 244, 286, 686, 498, 220, 553, 136, 741, 958, 904, 585, 591, 485, 249, 804, 485, 827, 417, 195, 97, 100, 675, 442, 363, 434, 421, 479, 885, 747, 56, 690, 670, 662, 101, 63, 413, 746, 348, 820, 883, 112, 255, 197, 195, 550, 460, 144, 433, 188, 286, 474, 256, 896, 946, 78, 454, 828, 883, 877, 564, 101, 52, 668, 554, 857, 16, 993, 96, 949, 772, 870, 243, 171, 417, 498, 493]
# ```
#
# 1. Convert the above lists into a dataframe.
# 2. Print the summary statistics.
# 3. Print the last 5 rows.
# 4. Plot the data in 4 separate plots. Make them as informative as possible.
#
# ---
#
# 3.
# Download the "WA_County_Boundaries" folder from the "Datasets" folder on GitHub.
# - Read the .shp file into Jupyter by using `variable_name = geopandas.read_file("path_to_.shp_file.shp")`
# - Plot the state using `variable_name.plot()`
# - Plot some information about the state by extracting two columns of data.

# %% [markdown]
# ### Lab Key*
#
# 1.

# %%
# part 1

data = [list(np.random.normal(0,1,5)) for i in range(5)]

# part 2

data = pd.DataFrame(data)
data.to_csv('data.csv', index=False)

# part 3

data = pd.read_csv('data.csv')

# part 4

for i in range(5):
    plt.plot([i for i in range(5)],data[str(i)])
plt.title('5 Normally Distributed Samples of 5')
plt.xlabel('# in Sample')
plt.ylabel('Normal Value')
# Out:
# Text(0, 0.5, 'Normal Value')

# %% [markdown]
# 2.

# %%
list1 = [655, 115, 26, 760, 282, 251, 229, 143, 755, 105, 693, 759, 914, 559, 90, 605, 433, 33, 31, 96, 224, 239, 518, 617, 28, 575, 204, 734, 666, 719, 559, 430, 226, 460, 604, 285, 829, 891, 7, 778, 826, 164, 715, 433, 349, 285, 160, 221, 981, 782, 345, 105, 95, 390, 100, 368, 868, 353, 619, 271, 827, 45, 748, 471, 550, 128, 997, 945, 388, 81, 566, 301, 850, 644, 634, 907, 883, 371, 592, 197, 722, 72, 47, 678, 234, 792, 297, 82, 876, 239, 888, 104, 390, 285, 465, 651, 855, 374, 167, 380]

list2 = [364, 215, 687, 274, 719, 960, 700, 664, 74, 624, 651, 176, 547, 747, 251, 168, 474, 389, 277, 948, 656, 705, 571, 225, 702, 333, 864, 787, 795, 58, 235, 842, 33, 825, 324, 411, 275, 68, 217, 936, 966, 581, 898, 736, 323, 218, 672, 512, 406, 906, 937, 659, 470, 147, 272, 143, 253, 763, 575, 552, 270, 765, 599, 439, 920, 598, 409, 371, 225, 142, 522, 506, 94, 774, 49, 882, 113, 157, 643, 164, 812, 697, 433, 611, 66, 395, 391, 611, 480, 542, 258, 995, 567, 882, 966, 12, 697, 739, 118, 699]

list3 = [907, 550, 769, 274, 788, 657, 349, 115, 301, 446, 162, 465, 4, 977, 740, 897, 737, 270, 996, 513, 781, 183, 520, 935, 109, 892, 641, 306, 862, 655, 520, 624, 204, 157, 383, 781, 166, 553, 977, 798, 945, 544, 941, 1, 614, 332, 501, 20, 115, 952, 372, 900, 852, 827, 315, 246, 60, 247, 900, 581, 970, 81, 88, 750, 498, 836, 71, 779, 546, 785, 129, 132, 676, 487, 970, 563, 170, 272, 541, 894, 622, 434, 988, 217, 952, 553, 774, 748, 707, 206, 731, 320, 409, 688, 666, 383, 449, 922, 530, 463]

list4 = [124, 254, 231, 66, 347, 22, 603, 568, 236, 603, 226, 8, 73, 725, 647, 61, 235, 70, 928, 33, 881, 339, 73, 527, 244, 286, 686, 498, 220, 553, 136, 741, 958, 904, 585, 591, 485, 249, 804, 485, 827, 417, 195, 97, 100, 675, 442, 363, 434, 421, 479, 885, 747, 56, 690, 670, 662, 101, 63, 413, 746, 348, 820, 883, 112, 255, 197, 195, 550, 460, 144, 433, 188, 286, 474, 256, 896, 946, 78, 454, 828, 883, 877, 564, 101, 52, 668, 554, 857, 16, 993, 96, 949, 772, 870, 243, 171, 417, 498, 493]

# %%
# part 1

data = pd.DataFrame({'List1':list1,
             'List2':list2,
             'List3':list3,
             'List4':list4})

# part 2

data.describe()

# part 3

data.tail()

# part 4

for i in range(4):
    plt.plot([i for i in range(100)], sorted(data['List'+str(i+1)]))
    plt.title('List #'+str(i+1))
    plt.xlabel('# in Sorted Version of List')
    plt.ylabel('Value')
    plt.show()

# %% [markdown]
# 4.

# %%
washington = gpd.read_file(r"path_on_your_device")

washington.plot('JURISDIC_4')
plt.title('Jurisdiction Identifier 4')
plt.axis('off')
plt.show()

washington.plot('JURISDIC_5')
plt.title('Jurisdiction Identifier 5')
plt.axis('off')
